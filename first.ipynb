# %%
import tensorflow as tf

# %%
scalar = tf.constant(20)
print(scalar)
# Out:
# tf.Tensor(20, shape=(), dtype=int32)

# %%
vector = tf.constant([10, 20, 30, 40])
print(vector)
# Out:
# tf.Tensor([10 20 30 40], shape=(4,), dtype=int32)

# %%
matrix = tf.constant([[1, 2, 3], [4, 5, 6]])
print(matrix)
# Out:
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)

# %%
matrix1 = tf.constant([[1, 1, 1], [1, 1, 1]])
print(matrix1)
# Out:
# tf.Tensor(
# [[1 1 1]
#  [1 1 1]], shape=(2, 3), dtype=int32)

# %%
matrix0 = tf.constant([[0, 0, 0], [0, 0, 0]])
print(matrix0)
# Out:
# tf.Tensor(
# [[0 0 0]
#  [0 0 0]], shape=(2, 3), dtype=int32)
