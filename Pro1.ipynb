# %%
import tensorflow as tf
import numpy as np
# Install scikit-learn if it is not available in the environment
try:
    from sklearn.preprocessing import OneHotEncoder
except ModuleNotFoundError:
    import sys
    # !{sys.executable} -m pip install scikit-learn
    from sklearn.preprocessing import OneHotEncoder

# %%
exp = np.array([1, 2, 3, 4, 5, 6], dtype = float)

train = np.array([20, 30, 40, 50, 60, 65], dtype = int)

projects = np.array([2, 3, 4, 5, 6, 7], dtype = int)

dept = np.array([ "IT", "HR", "IT", "Finance", "IT", "HR" ], dtype = str)

perf = np.array([45, 52, 61, 68, 75, 78], dtype = int)

# %%
encoder = OneHotEncoder()
department_encode = encoder.fit_transform(dept.reshape(-1, 1))
print(department_encode)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6 stored elements and shape (6, 3)>
#   Coords	Values
#   (0, 2)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 0)	1.0
#   (4, 2)	1.0
#   (5, 1)	1.0

# %%
X = np.column_stack((exp, train, projects, department_encode.toarray()))
Y = perf

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X.shape[1],)),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(
    optimizer = 'sgd',
    loss = 'mean_squared_error'
)

# %%
training = model.fit(X, Y, epochs = 20, verbose = 1)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step - loss: 5956.0610
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 2023305600.0000
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 823880.9375
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 791260.7500
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 759932.4375
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 729844.6875
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 700948.3125
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 673196.3125
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 646543.2500
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 620945.6875
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 596361.8125
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 572751.5000
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 550076.0625
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 528298.5625
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 507383.5312
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 487296.7188
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 468005.3750
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 449477.9688
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 431684.1250
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 414595.0000
