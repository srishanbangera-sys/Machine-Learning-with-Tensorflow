# %%
import tensorflow as tf
import numpy as np
# %pip install matplotlib

import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.23 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=8 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train / 255.0
y_train = y_train / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
# Out:
# /home/srishan-bangera/.pyenv/versions/3.10.19/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
training = model.fit(x_train, y_train, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.0987 - loss: 0.0038
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.0987 - loss: 1.7264e-06
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.0987 - loss: 3.0526e-07
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.0987 - loss: 8.3396e-08
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.0987 - loss: 2.7926e-08

# %%
from PIL import Image

filename = "number.webp"
image = Image.open(filename)

# %%
image = image.convert('L')  
image = image.resize((28,28))
image = np.array(image)

# %%
image = image / 255.0
image = np.expand_dims(image, axis=0)

prediction = model.predict(image)
predicted_class = np.argmax(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
